# %% [markdown]
# <a href="https://colab.research.google.com/github/Ellizence01/BSC_DPDM2025/blob/main/Ch3_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Import Data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Python&Data_viz2025/BSC_DPDM2025/flooding database.csv')

# %%
df
# Out:
#                            system:index  index threshold_type glide_index  \
# 0    DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1    DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2    DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3    DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4    DFO_1627_From_20000830_to_20000910   1627           otsu           0
# ..                                  ...    ...            ...         ...
# 908  DFO_4683_From_20180901_to_20181002   4683            std         NaN
# 909  DFO_4695_From_20181023_to_20181027   4695            std         NaN
# 910  DFO_4703_From_20181029_to_20181107   4703           otsu         NaN
# 911  DFO_4704_From_20181124_to_20181129   4704            std         NaN
# 912  DFO_4711_From_20181205_to_20181210   4711            std         NaN
#
#     dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# ...

# %% [markdown]
# # Missing Data

# %% [markdown]
# ## check Missing Data

# %% [markdown]
# drop ถ้ามี missing

# %%
df.shape
# Out:
# (913, 23)

# %% [markdown]
# ### Drop record ที่มี missig ออก

# %%
df.isnull().any()
# Out:
# system:index         False
# index                False
# threshold_type       False
# glide_index           True
# dfo_country          False
# dfo_other_country     True
# dfo_centroid_x       False
# dfo_centroid_y       False
# dfo_began            False
# dfo_ended             True
# dfo_validation        True
# dfo_dead             False
# dfo_displaced        False
# dfo_cause             True
# dfo_severity         False
# gfd_area             False
# gfd_exp_ghsl_ts       True
# gfd_exp_ghsl_2000     True
# gfd_exp_ghsl_2015    False
# Errors               False
# dif 2000             False
# dif 2015             False
# error 2000            True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              2
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %%
df_drop1 = df.dropna()
df_drop1.shape
# Out:
# (13, 23)

# %% [markdown]
# drop เฉพาะเกิด missing ในตัวแปรที่จะใช้
#
# - dfo_country
# - dfo_other_country
# - dfo_began
# - dfo_ended
# - dfo_dead
# - dfo_cause
# - dfo_severity

# %%
df_drop2 = df.dropna(subset=['dfo_country', 'dfo_other_country', 'dfo_began',
                             'dfo_ended', 'dfo_dead', 'dfo_cause', 'dfo_severity'])
df_drop2.shape
# Out:
# (637, 23)

# %%
df_drop2.head()
# Out:
#                          system:index  index threshold_type glide_index  \
# 0  DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1  DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2  DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3  DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4  DFO_1627_From_20000830_to_20000910   1627           otsu           0
#
#   dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 0   Australia                 0      143.697800      -31.268059   2/18/00
# 1  Madagascar                 0       47.295670      -15.782624   2/17/00
# 2     Romania           Hungary       22.415404       46.763746    4/5/00
# 3    Thailand           Vietnam      105.063841       11.242567   7/11/00
# 4       China            Russia      132.057679       43.773883   8/30/00
#
#   dfo_ended  ...              dfo_cause  dfo_severity  gfd_area  \
# ...

# %% [markdown]
# ## เติม Dummy

# %%
df[df.isnull()['dfo_other_country']]
# Out:
#                            system:index  index threshold_type  \
# 172  DFO_2415_From_20040110_to_20040119   2415            std
# 383  DFO_3089_From_20070530_to_20070603   3089            std
# 387  DFO_3097_From_20070611_to_20070624   3097            std
# 412  DFO_3136_From_20070721_to_20071015   3136            std
# 428  DFO_3166_From_20070726_to_20071010   3166            std
# ..                                  ...    ...            ...
# 908  DFO_4683_From_20180901_to_20181002   4683            std
# 909  DFO_4695_From_20181023_to_20181027   4695            std
# 910  DFO_4703_From_20181029_to_20181107   4703           otsu
# 911  DFO_4704_From_20181124_to_20181129   4704            std
# 912  DFO_4711_From_20181205_to_20181210   4711            std
#
#             glide_index         dfo_country dfo_other_country  dfo_centroid_x  \
# 172                   0                Iran               NaN       51.439491
# ...

# %%
df_filldummy= df.fillna({'dfo_other_country' :'unknown'})
df_filldummy
# Out:
#                            system:index  index threshold_type glide_index  \
# 0    DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1    DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2    DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3    DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4    DFO_1627_From_20000830_to_20000910   1627           otsu           0
# ..                                  ...    ...            ...         ...
# 908  DFO_4683_From_20180901_to_20181002   4683            std         NaN
# 909  DFO_4695_From_20181023_to_20181027   4695            std         NaN
# 910  DFO_4703_From_20181029_to_20181107   4703           otsu         NaN
# 911  DFO_4704_From_20181124_to_20181129   4704            std         NaN
# 912  DFO_4711_From_20181205_to_20181210   4711            std         NaN
#
#     dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# ...

# %% [markdown]
# ## เติม missing ด้วยค่ากลาง

# %%
df.groupby('dfo_cause').count()
# Out:
#                        system:index  index  threshold_type  glide_index  \
# dfo_cause
# Dam                              13     13              13           11
# Heavy rain                      749    749             749          554
# Snowmelt, Ice, Rain              52     52              52           45
# Tropical Storm, Surge            97     97              97           71
#
#                        dfo_country  dfo_other_country  dfo_centroid_x  \
# dfo_cause
# Dam                             13                 10              13
# Heavy rain                     749                530             749
# Snowmelt, Ice, Rain             52                 45              52
# Tropical Storm, Surge           97                 53              97
#
#                        dfo_centroid_y  dfo_began  dfo_ended  ...  \
# dfo_cause                                                    ...
# Dam                                13         13         13  ...
# ...

# %%
df_fillmode= df.fillna({'dfo_cause' :'heavy rain'})
df_fillmode
# Out:
#                            system:index  index threshold_type glide_index  \
# 0    DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1    DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2    DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3    DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4    DFO_1627_From_20000830_to_20000910   1627           otsu           0
# ..                                  ...    ...            ...         ...
# 908  DFO_4683_From_20180901_to_20181002   4683            std         NaN
# 909  DFO_4695_From_20181023_to_20181027   4695            std         NaN
# 910  DFO_4703_From_20181029_to_20181107   4703           otsu         NaN
# 911  DFO_4704_From_20181124_to_20181129   4704            std         NaN
# 912  DFO_4711_From_20181205_to_20181210   4711            std         NaN
#
#     dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# ...

# %% [markdown]
# ## เติมด้วย ตัวแทนของกลุ่ม

# %%
df.groupby(['dfo_severity','dfo_cause']).count()
# Out:
#                                     system:index  index  threshold_type  \
# dfo_severity dfo_cause
# 1.0          Dam                               9      9               9
#              Heavy rain                      464    464             464
#              Snowmelt, Ice, Rain              34     34              34
#              Tropical Storm, Surge            33     33              33
# 1.5          Dam                               3      3               3
#              Heavy rain                      163    163             163
#              Snowmelt, Ice, Rain               8      8               8
#              Tropical Storm, Surge            26     26              26
# 2.0          Dam                               1      1               1
#              Heavy rain                      122    122             122
#              Snowmelt, Ice, Rain              10     10              10
#              Tropical Storm, Surge            38     38              38
#
# ...

# %%
df_sever1 = df[df['dfo_severity'] == 1.0]
df_sever15 = df[df['dfo_severity'] == 1.5]
df_sever3 = df[df['dfo_severity'] == 2.0]

# %%
df_sever1 = df_sever1.fillna({'dfo_cause' :'heavy rain'})
df_sever15 = df_sever15.fillna({'dfo_cause' :'heavy rain'})
df_sever3 = df_sever3.fillna({'dfo_cause' :'Tropical Storm , Surge'})

# %%
df_fillgroup = pd.concat([df_sever1, df_sever15, df_sever3])

# %%
df_fillgroup.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              0
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# # Noisy Data

# %%
df['gfd_area']
# Out:
# 0        316.73
# 1        228.50
# 2         89.10
# 3       4322.47
# 4        740.33
#          ...
# 908     1866.91
# 909     2720.37
# 910    10019.87
# 911     6467.41
# 912     2475.92
# Name: gfd_area, Length: 913, dtype: float64

# %% [markdown]
# ## Explore data

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(df['gfd_area'])

# %% [markdown]
# ## Binning

# %% [markdown]
# ## ใช้ histogram ดู Bin ที่เหมาะสม

# %%
outputhist = plt.hist(df['gfd_area'],30)

# %%
outputhist[1] ##บอความถี่ในแต่ละช่วงชั้น
# Out:
# array([    0.        ,  3284.92066667,  6569.84133333,  9854.762     ,
#        13139.68266667, 16424.60333333, 19709.524     , 22994.44466667,
#        26279.36533333, 29564.286     , 32849.20666667, 36134.12733333,
#        39419.048     , 42703.96866667, 45988.88933333, 49273.81      ,
#        52558.73066667, 55843.65133333, 59128.572     , 62413.49266667,
#        65698.41333333, 68983.334     , 72268.25466667, 75553.17533333,
#        78838.096     , 82123.01666667, 85407.93733333, 88692.858     ,
#        91977.77866667, 95262.69933333, 98547.62      ])

# %% [markdown]
# # Task
# Define a Python function that takes a numerical value and the bin edges from the `outputhist` variable and returns the mean of the bin that the value falls into. Then, apply this function to the 'gfd_area' column of the DataFrame `df`.

# %% [markdown]
# ## define_bin_mean_function
#
# ### Subtask:
# Define a Python function to calculate the mean of the bin a value falls into, using the bin edges from the histogram.

# %% [markdown]
# **Reasoning**:
# Defining a Python function `get_bin_mean` to calculate the mean of the bin a given value falls into, based on the provided bin edges from the histogram.

# %%
import numpy as np

def get_bin_mean(value, bin_edges):
    """
    Calculates the mean of the bin a value falls into.

    Args:
        value (float): The numerical value.
        bin_edges (np.array): An array of bin edges from a histogram.

    Returns:
        float or None: The mean of the bin, or None if the value is outside all bins.
    """
    for i in range(len(bin_edges) - 1):
        if bin_edges[i] <= value < bin_edges[i+1]:
            return (bin_edges[i] + bin_edges[i+1]) / 2
    # Handle case where value is equal to the last bin edge
    if value == bin_edges[-1]:
        return (bin_edges[-2] + bin_edges[-1]) / 2 # Assuming the last bin is [bin_edges[-2], bin_edges[-1]]
    return None

print("Function `get_bin_mean` defined.")
# Out:
# Function `get_bin_mean` defined.

# %% [markdown]
# **Reasoning**:
# Now that the `get_bin_mean` function is defined, apply it to the 'gfd_area' column of the DataFrame `df` using the bin edges from `outputhist` to create a new column with the bin means.

# %%
get_bin_mean(7000,outputhist[1])
# Out:
# np.float64(8212.301666666666)

# %%
bin_edges = outputhist[1]
df['gfd_area_bin_mean'] = df['gfd_area'].apply(lambda x: get_bin_mean(x, bin_edges))
df[['gfd_area', 'gfd_area_bin_mean']].head()
# Out:
#    gfd_area  gfd_area_bin_mean
# 0    316.73        1642.460333
# 1    228.50        1642.460333
# 2     89.10        1642.460333
# 3   4322.47        4927.381000
# 4    740.33        1642.460333

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   A Python function, `get_bin_mean`, was successfully defined to calculate the mean of the histogram bin for a given numerical value and a set of bin edges.
# *   The function correctly identifies the bin a value belongs to, including a special case for values equal to the last bin edge. It returns `None` if a value falls outside the defined bins.
# *   The `get_bin_mean` function was successfully applied to the `gfd_area` column of the `df` DataFrame, using the bin edges extracted from `outputhist`.
# *   A new column, `gfd_area_bin_mean`, was added to the `df` DataFrame, containing the calculated bin mean for each corresponding value in the `gfd_area` column.
#
# ### Insights or Next Steps
# *   The `gfd_area_bin_mean` column provides a discretized and representative value for the `gfd_area` within its respective bins, which can be useful for further statistical analysis, visualization, or as a feature in machine learning models that require binned data.
# *   Review rows where `gfd_area_bin_mean` is `None` to understand if values in `gfd_area` fall outside the expected range of the histogram's bin edges, and decide on an appropriate handling strategy (e.g., imputation, exclusion, or re-evaluating bin definition).

# %%
plt.subplot(2,1,1)
plt.plot(df['gfd_area'].sort_values().reset_index(drop=True))
plt.subplot(2,1,2)
plt.plot(df['gfd_area_bin_mean'].sort_values().reset_index(drop=True))

# %% [markdown]
# ### outlier removal

# %%
outputbox = plt.boxplot(df['gfd_area'],vert=False,whis=10)

# %%
outputbox
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ce68e95d5b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ce68eb44ce0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ce68ee9a6f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ce68eb45220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ce68eb45520>],
#  'means': []}

# %%
outputbox['whiskers'][0].get_xdata()
# Out:
# array([608.6,   0. ])

# %%
outputbox['whiskers'][1].get_xdata()
# Out:
# array([ 7354.55, 68991.93])

# %%
outputbox['fliers'][0].get_xdata()
# Out:
# array([98547.62, 79213.43, 75030.8 , 78785.53, 88773.57, 97982.77])

# %% [markdown]
# ### remove outliers

# %%
flood_nooutlier = df[df['gfd_area'] < outputbox['whiskers'][1].get_xdata()[1]]

# %%
flood_nooutlierbox= plt.boxplot(flood_nooutlier['gfd_area'],vert=False,whis=10)

# %%
df[df['gfd_area'] == outputbox['fliers'][0].get_xdata()[0]]
# Out:
#                            system:index  index threshold_type glide_index  \
# 123  DFO_2208_From_20030416_to_20030528   2208            std           0
#
#     dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 123      Russia                 0       64.739289       55.453563   4/16/03
#
#     dfo_ended  ... dfo_severity  gfd_area  gfd_exp_ghsl_ts gfd_exp_ghsl_2000  \
# 123   5/28/03  ...          1.0  98547.62        1014245.0         1014245.0
#
#      gfd_exp_ghsl_2015  Errors  dif 2000  dif 2015  error 2000  \
# 123             931108       1         0     83137         1.0
#
#      gfd_area_bin_mean
# 123       96905.159667
#
# [1 rows x 24 columns]

# %% [markdown]
# # Data Integration

# %% [markdown]
# ## data exploration

# %%
project_df = pd.read_csv('/content/drive/MyDrive/Python&Data_viz2025/BSC_DPDM2025/P1.csv')

# %%
project_df.head(5)
# Out:
#    row_number                project_id                     name_en  \
# 0     20809.0  5ec3409884c1860019f3298d    Baan Laksiri Surin-Korco
# 1      4268.0             project_15905              Liberty Park 2
# 2      5849.0  62b2b082cb0d2c0014be01a6  Pleno Paholyothin-Saimai 2
# 3     21762.0              project_6010              Baan Thara Rin
# 4     10751.0             project_11312             The Forest Hill
#
#                       name_th propertytype_id propertytype_name_en  \
# 0  บ้านหลักศิริ สุรินทร์-คอโค               3             Townhome
# 1          ลิเบอร์ตี้ พาร์ค 2               2                Condo
# 2    พลีโน่ พหลโยธิน-สายไหม 2               3             Townhome
# 3              บ้านธารารินทร์               1       Detached House
# 4          เดอะ ฟอเรสต์ ฮิลล์               1       Detached House
#
#   propertytype_name_th  price_min     developer_id  \
# 0             ทาวน์โฮม  1490000.0   developer_7326
# ...

# %%
for i in project_df.columns:
  print(i)
# Out:
# row_number
# project_id
# name_en
# name_th
# propertytype_id
# propertytype_name_en
# propertytype_name_th
# price_min
# developer_id
# developer_name_en
# developer_name_th
# latitude
# longitude
# neighborhood_id
# neighborhood_name_en
# neighborhood_name_th
# subdistrict_id
# subdistrict_name_en
# subdistrict_name_th
# district_id
# district_name_en
# district_name_th
# province_id
# province_name_en
# province_name_th
# zipcode
# count_elevator
# count_elevator_service
# count_floor
# count_parking
# count_tower
# count_unit
# count_unittype
# facility_clubhouse
# facility_fitness
# facility_meeting
# facility_park
# facility_playground
# facility_pool
# facility_security
# date_created
# date_finish
# date_updated
# source
# url_project
# day

# %%
unit_df = pd.read_csv('/content/drive/MyDrive/Python&Data_viz2025/BSC_DPDM2025/Op.csv')

# %%
unit_df.head(5)
# Out:
#    row_number               unittype_id                project_id  \
# 0       37586            unittype_35602             project_15270
# 1        9427             unittype_4487              project_1476
# 2       12994            unittype_37624             project_16674
# 3       19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4       10907             unittype_8344              project_2821
#
#                name_th  propertytype_id propertytype_name_en  \
# 0               Studio                2                Condo
# 1              ภัทรสิน                3             Townhome
# 2               Type B                3             Townhome
# 3      ทาวน์โฮมสองชั้น                3             Townhome
# 4  2 Bedroom (ขายแล้ว)                2                Condo
#
#   propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 0                คอนโด                NaN             30.0  3700000.0  ...
# ...

# %%
for j in unit_df.columns:
  print(j)
# Out:
# row_number
# unittype_id
# project_id
# name_th
# propertytype_id
# propertytype_name_en
# propertytype_name_th
# area_total_min_wa
# area_usable_min
# price_min
# count_airconditioner
# count_elevator
# count_floor_internal
# count_parking
# count_room_bath
# count_room_bed
# count_room_dinning
# count_room_guest
# count_room_kitchen
# count_room_living
# count_room_maid
# count_room_storage
# count_room_utility
# date_created
# date_updated
# source
# url_unittype
# day

# %% [markdown]
# ### Add more column to the table (X-Data Integration)

# %%
unit_df['project_id'].map(project_df.set_index('project_id')['name_th'])
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipython-input-2613396769.py in <cell line: 0>()
# ----> 1 unit_df['project_id'].map(project_df.set_index('project_id')['name_th'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4698         dtype: object
#    4699         """
# -> 4700         new_values = self._map_values(arg, na_action=na_action)
#    4701         return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702             self, method="map"
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# ...

# %%
unit_df['project_id'].map(project_df.set_index('project_id')['name_th','developer_name_th',
                                                             'neighborhood_name_th','subdistrict_name_th',
                                                             'district_name_th','province_name_th'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('name_th', 'developer_name_th', 'neighborhood_name_th', 'subdistrict_name_th', 'district_name_th', 'province_name_th')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## Deduplication

# %% [markdown]
# ดูก่อนว่า Data มัน Duplicate ยังไง

# %%
project_df.duplicated().any()
# Out:
# np.True_

# %%
project_df.duplicated().sum()
# Out:
# np.int64(2)

# %%
project_df[project_df.duplicated(subset=['project_id'], keep=False)]
# Out:
#        row_number                project_id  \
# 0         20809.0  5ec3409884c1860019f3298d
# 8          3795.0  5f04029cb285eb00194de1dd
# 23        20554.0              project_7343
# 24        12456.0              project_4054
# 34         5047.0  5f34e60ec801fb0019dacbd6
# ...           ...                       ...
# 23855      6509.0  6177730c551dd10015a6916d
# 23857      2954.0             project_13943
# 23860     13953.0              project_3144
# 23861     17686.0              project_3585
# 23863     12360.0              project_9316
#
#                                      name_en  \
# 0                   Baan Laksiri Surin-Korco
# 8                           City park sakaeo
# 23                       Baan Nantana Garden
# 24               Cubist Townhome Sanambinnam
# 34                       Taraville Pechabura
# ...                                      ...
# 23855                  Bliss Baankhai Rayong
# 23857                 Baan Chalongsuk Phuket
# ...

# %%
project_df[project_df.duplicated(keep = False)]
# Out:
#        row_number project_id name_en        name_th propertytype_id  \
# 138           NaN  ขนส่งปทุม    3611      BAN CHANG         บ้านฉาง
# 5610          NaN  ขนส่งปทุม    3611      BAN CHANG         บ้านฉาง
# 8103          NaN  ขนส่งปทุม    3656  BANG PHO NUEA   บางโพธิ์เหนือ
# 10204         NaN  ขนส่งปทุม    3656  BANG PHO NUEA   บางโพธิ์เหนือ
#
#       propertytype_name_en propertytype_name_th      price_min developer_id  \
# 138                   3600  MUEANG PATHUM THANI  เมืองปทุมธานี         3599
# 5610                  3600  MUEANG PATHUM THANI  เมืองปทุมธานี         3599
# 8103                  3647             SAM KHOK         สามโคก         3599
# 10204                 3647             SAM KHOK         สามโคก         3599
#
#       developer_name_en  ... facility_park  facility_playground  \
# 138        Pathum Thani  ...           NaN                  NaN
# 5610       Pathum Thani  ...           NaN                  NaN
# ...

# %%
project_df_dedup = project_df.drop_duplicates()

# %%
project_df_dedup = project_df.drop_duplicates(subset=['project_id'],keep = 'last')

# %%
unit_df['project_id'].map(project_df_dedup.set_index('project_id')['name_th'])
# Out:
# 0             ไลฟ์ แอท รัชดา - สุทธิสาร
# 1                     บ้านสวนทรัพย์ธานี
# 2                         สกายไลน์ อมตะ
# 3         รุ่งเรืองทรัพย์วิลเลจ @ กะปาง
# 4        เดอะ เทมโป แกรนด์ สาทร-วุฒากาศ
#                       ...
# 43369            บ้านคุรุสภา นครราชสีมา
# 43370                    บ้านเต็มสิริ 1
# 43371                      พระเงิน เพลส
# 43372             บ้านไทยวิลล่า ศรีราชา
# 43373    แกรนด์ คอนโดมิเนียม วุฒากาศ 57
# Name: project_id, Length: 43374, dtype: object

# %%
unit_df['ชื่อโครงการ']= unit_df['project_id'].map(project_df_dedup.set_index('project_id')['name_th'])

# %% [markdown]
# hw3 กลับไปเติมข้อมูล columns ที่จำเป็นที่เหลือ

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ## Column Alignment

# %% [markdown]
# ## Add data source column
